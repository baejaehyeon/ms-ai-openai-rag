# %%
import os
import json
import requests
import time
from openai import AzureOpenAI

client = AzureOpenAI(
  azure_endpoint = os.getenv("AZURE_OAI_ENDPOINT"),
  api_key= os.getenv("AZURE_OAI_KEY"),
  api_version="2024-05-01-preview"
)

# 도우미 객체 생성(Azure OpenAI 벡터 저장소 ID : vs_LLnqkbYWTf1rCbvdsM789HzP)
assistant = client.beta.assistants.create(
  model="gpt-4o-mini", # replace with model deployment name.
  instructions="",
  tools=[{"type":"file_search"}],
  tool_resources={"file_search":{"vector_store_ids":["vs_LLnqkbYWTf1rCbvdsM789HzP"]}},
  temperature=1,
  top_p=1
)

# Create a thread
thread = client.beta.threads.create()

# Add a user question to the thread
message = client.beta.threads.messages.create(
  thread_id=thread.id,
  role="user",
  content="백터 저장소에 저장된 파일 분석해줘" # Replace this with your prompt
)



# Run the thread
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id
)

# Looping until the run completes or fails
while run.status in ['queued', 'in_progress', 'cancelling']:
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

if run.status == 'completed':
  messages = client.beta.threads.messages.list(
    thread_id=thread.id
  )
  #print(messages.json())
  print(messages.data[0].content[0].text.value)
elif run.status == 'requires_action':
  # the assistant requires calling some functions
  # and submit the tool outputs back to the run
  pass
else:
  print(run.status)
# Out:
# C:\Users\EL32\AppData\Local\Temp\ipykernel_19572\1354904758.py:24: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   thread = client.beta.threads.create()
# C:\Users\EL32\AppData\Local\Temp\ipykernel_19572\1354904758.py:27: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   message = client.beta.threads.messages.create(
# C:\Users\EL32\AppData\Local\Temp\ipykernel_19572\1354904758.py:36: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run = client.beta.threads.runs.create(
# C:\Users\EL32\AppData\Local\Temp\ipykernel_19572\1354904758.py:44: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   run = client.beta.threads.runs.retrieve(
# C:\Users\EL32\AppData\Local\Temp\ipykernel_19572\1354904758.py:50: DeprecationWarning: The Assistants API is deprecated in favor of the Responses API
#   messages = client.beta.threads.messages.list(
# 파일은 펭귄의 부리 길이와 깊이를 종(species)별로 시각화하는 산점도를 생성하는 Python 코드를 포함하고 있습니다. 이 코드는 다음과 같은 주요 기능을 수행합니다:
#
# 1. **데이터프레임 로드**: 두 개의 데이터프레임을 입력받습니다(현재 코드에서는 `dataframe2`는 사용되지 않고 있습니다).
# 2. **산점도 그리기**: `seaborn` 라이브러리를 사용하여 부리 길이(`bill_length_mm`)와 부리 깊이(`bill_depth_mm`)를 x와 y축으로 설정하고, 두 가지 변수를 종별로 구분하여 색상을 다르게 설정합니다.
# 3. **이미지 저장**: 생성된 산점도를 "scatterplot.png"라는 파일명으로 저장합니다.
# 4. **Azure ML과 통합**: Azure Machine Learning 환경에서 실행되는 경우, 그래픽 파일을 Azure의 런 컨텍스트에 업로드합니다.
#
# 이 코드는 통계적 데이터 분석 및 결과 시각화 과정에서 유용하게 사용될 수 있습니다【4:0†source】.
