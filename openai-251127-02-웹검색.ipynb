# %%
import os
from openai import OpenAI

from dotenv import load_dotenv


# .env 환경변수 로드
load_dotenv()
AZURE_OAI_ENDPOINT = os.getenv("AZURE_OAI_ENDPOINT")
AZURE_OAI_KEY = os.getenv("AZURE_OAI_KEY")
AZURE_OAI_DEPLOYMENT = os.getenv("AZURE_OAI_DEPLOYMENT")

client = OpenAI(
    api_key=os.getenv("AZURE_OAI_KEY"),
    base_url='https://8ai022-openai.openai.azure.com/openai/v1/',
)

response = client.responses.create(   
  model=os.getenv("AZURE_OAI_DEPLOYMENT"), # Replace with your model deployment name
  tools=[{"type": "web_search_preview"}], 
  input="현재 서울의 날씨를 얘기해줘."
)

print(response.output_text)
# Out:
# 현재 서울의 날씨는 맑고 기온은 약 5°C입니다. 바람은 시속 3~8km로 불고 있으며, 습도는 약 66%입니다. 오늘 하루 기온은 최대 6°C에서 최소 3°C로 예상됩니다. 구름이 많고 밤에는 조금 더 내려갈 것으로 보입니다. 제일 좋은 외출 시간은 낮 기온이 높을 때입니다.
#
# 자세한 내용은 [AccuWeather](https://www.accuweather.com/en/kr/seoul/226081/weather-forecast/226081)에서 확인할 수 있습니다.
